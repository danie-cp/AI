# %% [markdown]
# <a href="https://colab.research.google.com/github/danie-cp/AI/blob/main/Problem2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# @Author: Daniela Cruz Perez
#
# Date: 9/26/25
#
# BFS: Find potential Friends

# %% [markdown]
# Returns the immediate (connected) friends of a given user's immediate friends

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from collections import deque

# Start the graph search from root using a doubly-ended queue

def PotentialFriends(G, root):

  # deque is list-like container with fast appends and pops on either end
    visited, queue = set(), deque([root])
    visited.add(root)

    if root not in G:                            #Checks if the person is in the graph
      print("No friends")
      return

    k= 0                                         #the number of parent nodes + their first-level children
    num_iter =0                                  #the number of level
    i =0                                         #the hypothetical iteration for the visited queue


      ####################################################################################################
      # We are interested when the queue set only contains the children of the nodes in the visited set.
      # To keep track of this occurance, as i iterates, k contains the number of parent nodes and their children.
      # When k and i are equal, this is when the new children are in the queue.
      # num_iter tracks the amount of times this occur, thus its level.
      ##########################################################################################################


    # Keep exploring as long as the queue is not empty
    while queue:

        if (i ==k):
          k = k + len(queue)
          num_iter = num_iter+1

          if (num_iter >2):              #This exludes the root and their direct friends and returns their immediate friend's immediate friends
           print(queue)
           break;

        i = i+1

        # Dequeue a vertex from queue
        vertex = queue.popleft()

        # If not visited, mark it as visited, and enqueue it
        for neighbor in G[vertex]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

# %%
G = {
  'Adam' : ["Maria"],
  'Maria' : ['Adam','Maya','Sophia','David'],
  'David' : ['Maria','Maya'],
  'Maya' : ['Maria','David', 'Sophia'],
  'Sophia' : ['Maria','Maya']
}


PotentialFriends(G, "Adam")
PotentialFriends(G, "David")
PotentialFriends(G, "Sophia")
# Out:
# deque(['Maya', 'Sophia', 'David'])
# deque(['Adam', 'Sophia'])
# deque(['Adam', 'David'])
