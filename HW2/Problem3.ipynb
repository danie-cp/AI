# %% [markdown]
# <a href="https://colab.research.google.com/github/danie-cp/AI/blob/main/Problem3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# @Author: Daniela Cruz Perez
#
# Date: 9/26/25
#
# DFS: Maze

# %% [markdown]
# Define the Start State and the Goal State. Returns Sucess if the goal is reachable and return Failure if not from the start state.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from collections import deque

# Start the graph search from root using a doubly-ended queue
# both these combinations work for DFS: append/pop and appendleft/popleft

def DFS(graph, root, goal):

    # deque is list-like container with fast appends and pops on either end
    visited, queue = set(), deque([root])
    visited.add(root)

    # Keep exploring as long as the queue is not empty
    while queue:

        # Dequeue a vertex from queue
        vertex = queue.pop()


        # If not visited, mark the node as visited and enqueue it
        # Use reversed() to enforce left-to-right ordering

        for neighbor in reversed(graph[vertex]):
            if neighbor not in visited:

                visited.add(neighbor)
                visited.add(neighbor)
                queue.append(neighbor)

    if goal in visited:                        #if the goal is never visited, then it was never reached
      print("Success!")
    else:
      print("Failure!")

# %%
graph1 = {
  '0' : ['1', '5'],
  '1' : ['0', '2'],
  '2' : ['1', '3'],
  '3' : ['2','4'],
  '4' : ['3'],
  '5':  ['0', '6'],
  '6' : ['5','7'],
  '7' : ['6','8'],
  '8' : ['7','9','12'],
  '9' : ['8','10'],
  '10' : ['9','11'],
  '11' : ['10'],
  '12' : ['8','13'],
  '13' : ['12','14'],
  '14' : ['13','15'],
  '15' : ['14','16'],
  '16' : ['15','17'],
  '17' : ['16','18'],
  '18' : ['17','19','21'],
  '19' : ['18','20'],
  '20' : ['19'],
  '21' : ['18','22','25'],
  '22' : ['21','23'],
  '23' : ['22','24'],
  '24' : ['23'],
  '25' : ['21','26'],
  '26' : ['25','27'],
  '27' : ['26','28'],
  '28' : ['27','29'],
  '29' : ['28','30'],
  '30' : ['29','31'],
  '31' : ['30','32','35'],
  '32' : ['31','33'],
  '33' : ['32','34'],
  '34' : ['33'],
  '35' : ['31','36'],
  '36' : ['35','37'],
  '37' : ['36','38'],
  '38' : ['37','39'],
  '39' : ['38','40'],
  '40' : ['39','41'],
  '41' : ['40','42'],
  '42' : ['41','43','45'],
  '43' : ['42','44'],
  '44' : ['43'],
  '45' : ['42','46'],
  '46' : ['45','47','48'],
  '47' : ['46'],
  '48' : ['46','49'],
  '49' : ['48'],                            #this is the goal state
}



DFS(graph1, '0','49')
# Out:
# Success!

# %%
graph1 = {
  '0' : ['1', '5'],
  '1' : ['0', '2'],
  '2' : ['1', '3'],
  '3' : ['2','4'],
  '4' : ['3'],
  '5':  ['0', '6'],
  '6' : ['5','7'],
  '7' : ['6'],
  '8' : ['9','10'],
  '9' : ['8'],
  '10' : ['8','11'],
  '11' : ['10','12'],
  '12' : ['11','13'],
  '13' : ['12','14'],
  '14' : ['13','15'],
  '15' : ['14','16'],
  '16' : ['15','17'],
  '17' : ['16','18'],
  '18' : ['17','19','21'],
  '19' : ['18','20'],
  '20' : ['19'],
  '21' : ['18','22','25'],
  '22' : ['21','23'],
  '23' : ['22','24'],
  '24' : ['23'],
  '25' : ['21','26'],
  '26' : ['25','27'],
  '27' : ['26','28'],
  '28' : ['27','29'],
  '29' : ['28','30'],
  '30' : ['29','31'],
  '31' : ['30','32','35'],
  '32' : ['31','33'],
  '33' : ['32','34'],
  '34' : ['33'],
  '35' : ['31','36'],
  '36' : ['35','37'],
  '37' : ['36','38'],
  '38' : ['37','39'],
  '39' : ['38','40'],
  '40' : ['39','41'],
  '41' : ['40','42'],
  '42' : ['41','43','45'],
  '43' : ['42','44'],
  '44' : ['43'],
  '45' : ['42','46'],
  '46' : ['45','47','48'],
  '47' : ['46'],
  '48' : ['46','49'],
  '49' : ['48'],                            #this is the goal state
}



DFS(graph1, '0','49')
# Out:
# Failure!
